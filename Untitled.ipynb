# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km
from keras.models import Sequential
from keras import activations,initializers,regularizers,constraints
from keras.layers import Dense

# %%
df=pd.read_csv("/content/winequality-red (1).csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
x=df.drop(columns=['quality'])
y=df['quality']

# %%
train_X,test_X,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=123)

# %%
train_X.shape
# Out:
# (1119, 11)

# %%
model=Sequential()
model.add(Dense(units=11,kernel_initializer='uniform',activation='relu',input_dim=11))
model.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=4,kernel_initializer='uniform',activation='relu'))
model.add(Dense(units=1,kernel_initializer='uniform',activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4)              │            28 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 237 (948.00 B)
#  Trainable params: 237 (948.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (1119, 11)
# (1119,)

# %%
model.fit(train_X,train_y,epochs=50,batch_size=32,validation_split=0.1)
mse=model.evaluate(test_X,test_y)
print(f'Test mean squared error:{mse}')
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 31.8336 - val_loss: 32.7617
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.2139 - val_loss: 24.8816
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.6909 - val_loss: 6.3201
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1125 - val_loss: 5.5492
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1727 - val_loss: 4.4729
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0691 - val_loss: 3.6821
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1713 - val_loss: 2.8675
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6139 - val_loss: 2.1093
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8047 - val_loss: 1.5149
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2690 - val_loss: 1.1226
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8289 - val_loss: 0.8703
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7024 - val_loss: 0.8184
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6386 - val_loss: 0.7648
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6260 - val_loss: 0.7513
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6516 - val_loss: 0.7381
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6622 - val_loss: 0.7809
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6157 - val_loss: 0.7591
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6660 - val_loss: 0.7187
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6288 - val_loss: 0.7490
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6177 - val_loss: 0.7160
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5587 - val_loss: 0.6923
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6000 - val_loss: 0.6848
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5667 - val_loss: 0.7111
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5932 - val_loss: 0.6906
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5636 - val_loss: 0.6809
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5274 - val_loss: 0.6889
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5913 - val_loss: 0.6508
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5360 - val_loss: 0.6390
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5326 - val_loss: 0.6730
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5491 - val_loss: 0.6254
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5804 - val_loss: 0.6209
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5401 - val_loss: 0.6447
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5767 - val_loss: 0.6036
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5057 - val_loss: 0.6177
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5073 - val_loss: 0.6278
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5256 - val_loss: 0.6304
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5365 - val_loss: 0.6155
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5287 - val_loss: 0.5984
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5310 - val_loss: 0.6200
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5014 - val_loss: 0.5670
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5078 - val_loss: 0.5762
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5294 - val_loss: 0.5667
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4573 - val_loss: 0.6046
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5332 - val_loss: 0.5751
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4722 - val_loss: 0.5679
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4643 - val_loss: 0.5752
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4839 - val_loss: 0.5615
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4510 - val_loss: 0.5648
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4907 - val_loss: 0.5778
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5088 - val_loss: 0.5340
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4695
# Test mean squared error:0.46576493978500366

# %%
predictions=model.predict(test_X)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
predictions
# Out:
# array([[6.4887977],
#        [5.4034843],
#        [5.2641   ],
#        [6.2600784],
#        [5.4331493],
#        [5.7082276],
#        [6.1905584],
#        [5.675749 ],
#        [5.7011614],
#        [5.814148 ],
#        [5.232916 ],
#        [6.698058 ],
#        [5.7425184],
#        [5.9470534],
#        [5.9541364],
#        [6.289214 ],
#        [5.2137303],
#        [6.0420566],
#        [5.9522367],
#        [5.44714  ],
#        [5.9160385],
#        [5.7425184],
#        [5.7640433],
#        [5.39231  ],
#        [5.49509  ],
#        [5.41892  ],
#        [6.01933  ],
#        [5.8169193],
#        [6.1507244],
#        [5.7894506],
#        [5.189086 ],
#        [6.352371 ],
#        [5.492016 ],
#        [5.2523413],
#        [6.2190447],
#        [5.150447 ],
#        [5.676855 ],
#        [6.327679 ],
#        [5.2915173],
#        [5.25317  ],
#        [5.573659 ],
#        [6.0991964],
#        [6.169861 ],
#        [5.7595716],
#        [5.5588326],
#        [5.394386 ],
#        [5.675676 ],
#        [5.20165  ],
#        [5.8868055],
#        [5.702526 ],
#        [5.5775914],
#        [6.488691 ],
#        [5.504042 ],
#        [6.018838 ],
#        [5.2083583],
#        [6.5439425],
#        [5.261876 ],
#        [5.256174 ],
#        [5.718216 ],
#        [5.3481846],
#        [5.433378 ],
#        [5.961315 ],
#        [5.477738 ],
#        [5.8195157],
#        [6.647896 ],
#        [6.0482035],
#        [6.278729 ],
#        [5.5379596],
#        [5.4033585],
#        [6.270375 ],
#        [5.4594045],
#        [5.8996444],
#        [5.8576565],
#        [6.025421 ],
#        [5.7778106],
#        [5.7612853],
#        [5.221716 ],
#        [5.261799 ],
#        [5.896097 ],
#        [5.8314095],
#        [5.195407 ],
#        [5.2309275],
#        [6.208612 ],
#        [5.280938 ],
#        [5.6756554],
#        [5.803915 ],
#        [6.143959 ],
#        [5.2049046],
#        [5.3359747],
#        [5.037109 ],
#        [5.698809 ],
#        [5.896755 ],
#        [5.550401 ],
#        [6.1471715],
#        [6.322994 ],
#        [5.6614237],
#        [6.820487 ],
#        [6.374642 ],
#        [6.1243258],
#        [5.594345 ],
#        [6.2666416],
#        [6.180011 ],
#        [5.2551613],
#        [6.066078 ],
#        [5.5889883],
#        [5.6182528],
#        [5.838489 ],
#        [6.142789 ],
#        [6.3021965],
#        [6.1013947],
#        [5.8114014],
#        [5.996774 ],
#        [5.539831 ],
#        [6.187535 ],
#        [6.0348716],
#        [6.5618186],
#        [5.548773 ],
#        [5.2493544],
#        [5.620519 ],
#        [5.303424 ],
#        [5.6304507],
#        [6.3181105],
#        [5.742686 ],
#        [5.8853726],
#        [5.663083 ],
#        [5.4357033],
#        [6.2746944],
#        [5.8150253],
#        [6.104765 ],
#        [5.476656 ],
#        [5.611239 ],
#        [6.2376647],
#        [5.3341746],
#        [6.2119155],
#        [5.900415 ],
#        [5.499449 ],
#        [5.7810173],
#        [5.339775 ],
#        [6.4383807],
#        [5.884528 ],
#        [5.2668076],
#        [5.9210196],
#        [5.7363753],
#        [6.226766 ],
#        [5.577797 ],
#        [5.5144596],
#        [5.6744785],
#        [6.124648 ],
#        [5.4075646],
#        [6.4734926],
#        [5.233772 ],
#        [5.957783 ],
#        [5.816045 ],
#        [6.377609 ],
#        [5.9211597],
#        [5.888789 ],
#        [6.2820835],
#        [5.339197 ],
#        [5.4455175],
#        [5.6184473],
#        [5.3150816],
#        [6.270375 ],
#        [6.4611373],
#        [5.585008 ],
#        [5.3368626],
#        [5.8191547],
#        [5.6276   ],
#        [5.4955072],
#        [5.8603477],
#        [5.804126 ],
#        [5.481695 ],
#        [5.465671 ],
#        [5.810402 ],
#        [5.868352 ],
#        [5.7517014],
#        [5.9505286],
#        [5.658656 ],
#        [5.550401 ],
#        [5.823886 ],
#        [5.3289037],
#        [5.864586 ],
#        [5.4394937],
#        [6.1775074],
#        [5.981221 ],
#        [6.4051228],
#        [6.2939844],
#        [6.143087 ],
#        [5.875606 ],
#        [5.3890886],
#        [5.582295 ],
#        [6.885393 ],
#        [6.0336123],
#        [5.9198914],
#        [5.6413536],
#        [5.4939194],
#        [6.3193913],
#        [5.658656 ],
#        [6.1918836],
#        [5.498557 ],
#        [5.394571 ],
#        [6.1012745],
#        [5.987395 ],
#        [6.0328636],
#        [6.287728 ],
#        [5.6755285],
#        [6.0449705],
#        [5.769874 ],
#        [6.0512094],
#        [5.823275 ],
#        [5.1923027],
#        [6.1170015],
#        [5.714625 ],
#        [6.045082 ],
#        [5.7189946],
#        [5.4910927],
#        [5.778815 ],
#        [5.9467316],
#        [6.1135054],
#        [5.842812 ],
#        [6.071916 ],
#        [6.2503853],
#        [5.2780247],
#        [5.567743 ],
#        [5.8392253],
#        [6.0509834],
#        [5.703093 ],
#        [6.289214 ],
#        [6.356159 ],
#        [5.3429303],
#        [5.589877 ],
#        [5.2563295],
#        [5.63756  ],
#        [5.909642 ],
#        [5.6263657],
#        [5.905613 ],
#        [5.805601 ],
#        [5.3782816],
#        [5.640472 ],
#        [6.0199623],
#        [5.800544 ],
#        [5.4107423],
#        [5.5757265],
#        [5.716833 ],
#        [5.6611757],
#        [5.3825607],
#        [5.897909 ],
#        [5.562812 ],
#        [6.46614  ],
#        [5.7333083],
#        [6.232947 ],
#        [5.773525 ],
#        [5.4594045],
#        [5.4345407],
#        [5.8632116],
#        [5.757261 ],
#        [6.214798 ],
#        [5.3842325],
#        [5.9360046],
#        [5.3972044],
#        [5.2349834],
#        [5.374571 ],
#        [5.210527 ],
#        [5.7931185],
#        [5.5477133],
#        [5.930917 ],
#        [6.7397346],
#        [5.6594396],
#        [5.7775307],
#        [5.439726 ],
#        [5.474213 ],
#        [6.2671156],
#        [6.564468 ],
#        [5.8481727],
#        [5.9482355],
#        [6.0719323],
#        [5.490488 ],
#        [5.390934 ],
#        [5.31203  ],
#        [5.338863 ],
#        [5.620171 ],
#        [6.2671156],
#        [6.2701287],
#        [5.4831924],
#        [5.46552  ],
#        [5.2999716],
#        [5.137828 ],
#        [6.4051228],
#        [6.204218 ],
#        [5.860773 ],
#        [5.9396405],
#        [6.1574574],
#        [5.6192846],
#        [5.829804 ],
#        [6.0336123],
#        [5.449467 ],
#        [6.062242 ],
#        [6.2344656],
#        [5.8856864],
#        [5.9979343],
#        [5.6854324],
#        [5.261318 ],
#        [5.980362 ],
#        [5.4697804],
#        [6.043209 ],
#        [5.380056 ],
#        [5.350333 ],
#        [6.071916 ],
#        [5.6201987],
#        [5.8491745],
#        [5.856336 ],
#        [5.2588778],
#        [5.7258334],
#        [5.8553534],
#        [6.456419 ],
#        [5.631975 ],
#        [5.590241 ],
#        [5.9859633],
#        [5.8666887],
#        [5.4877543],
#        [5.2307377],
#        [6.247882 ],
#        [5.554099 ],
#        [5.742415 ],
#        [5.374571 ],
#        [5.358527 ],
#        [5.8290567],
#        [6.4622393],
#        [6.350683 ],
#        [5.280836 ],
#        [5.48578  ],
#        [6.4099717],
#        [5.743723 ],
#        [5.517274 ],
#        [5.241874 ],
#        [5.4877543],
#        [5.628247 ],
#        [5.247463 ],
#        [6.312631 ],
#        [5.7378798],
#        [5.496599 ],
#        [5.8122554],
#        [5.5691667],
#        [6.1967745],
#        [5.4145164],
#        [6.173985 ],
#        [5.8288536],
#        [5.4455175],
#        [5.993823 ],
#        [5.306697 ],
#        [6.5211296],
#        [5.8562765],
#        [5.433378 ],
#        [5.5251164],
#        [6.0028114],
#        [5.3485007],
#        [5.549327 ],
#        [5.712648 ],
#        [5.8436866],
#        [5.304117 ],
#        [5.3079457],
#        [5.548724 ],
#        [6.1793156],
#        [5.239398 ],
#        [6.091689 ],
#        [5.724617 ],
#        [5.621655 ],
#        [6.188111 ],
#        [5.6565113],
#        [5.885374 ],
#        [5.510878 ],
#        [5.9033027],
#        [5.7186403],
#        [6.292407 ],
#        [5.434059 ],
#        [6.1865697],
#        [6.4241347],
#        [5.5889883],
#        [5.9754887],
#        [5.491383 ],
#        [6.291335 ],
#        [5.535387 ],
#        [5.8049197],
#        [6.017412 ],
#        [6.094955 ],
#        [5.804498 ],
#        [6.558507 ],
#        [5.9616632],
#        [5.3575287],
#        [5.3779187],
#        [5.3780193],
#        [5.675122 ],
#        [5.6561546],
#        [5.2290063],
#        [6.4100895],
#        [5.716472 ],
#        [6.052007 ],
#        [5.5684304],
#        [6.223283 ],
#        [6.0807676],
#        [5.975678 ],
#        [6.6051116],
#        [5.4674125],
#        [5.5616636],
#        [5.573944 ],
#        [5.819516 ],
#        [5.426777 ],
#        [5.3211994],
#        [5.4646654],
#        [5.2132745],
#        [5.9616046],
#        [5.48574  ],
#        [5.6976957],
#        [5.3392563],
#        [5.582295 ],
#        [5.6146374],
#        [6.258238 ],
#        [6.1188135],
#        [5.3025517],
#        [5.582992 ],
#        [5.7495584],
#        [5.8290567],
#        [5.5623074],
#        [5.9487453],
#        [5.749054 ],
#        [5.4893484],
#        [5.4316163],
#        [5.2187214],
#        [5.716833 ],
#        [5.980362 ],
#        [6.0602236],
#        [5.890558 ],
#        [6.2432895],
#        [6.124369 ],
#        [5.4462547],
#        [5.4189177],
#        [5.608617 ],
#        [5.897191 ],
#        [5.4843307],
#        [5.539673 ],
#        [5.2915173],
#        [5.984795 ],
#        [5.511755 ],
#        [6.3986254],
#        [5.9793506],
#        [5.39935  ],
#        [6.434416 ],
#        [5.296189 ],
#        [5.410699 ],
#        [5.7334185],
#        [5.6860347],
#        [6.0245585],
#        [5.469795 ],
#        [5.323279 ],
#        [5.1567287],
#        [6.123969 ],
#        [6.3201437],
#        [5.359618 ],
#        [5.9184604],
#        [5.4549766],
#        [5.379659 ],
#        [6.764647 ],
#        [6.3290296],
#        [6.354643 ],
#        [5.8500404],
#        [5.7235675],
#        [6.4249353],
#        [5.5442696],
#        [5.60862  ],
#        [5.496599 ],
#        [6.4508677],
#        [5.823299 ],
#        [6.46614  ],
#        [6.5717006],
#        [5.4508123],
#        [5.394289 ],
#        [5.6097507],
#        [5.9242   ],
#        [5.420231 ],
#        [6.185285 ],
#        [5.486033 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(df['quality'], bins=10)
plt.title("Distribution of Wine Quality")
plt.xlabel("Quality")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.hist(df['alcohol'], bins=10)
plt.title("Distribution of Alcohol")
plt.xlabel("Alcohol")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
quality_levels = sorted(df['quality'].unique())
data = [df[df['quality'] == q]['alcohol'] for q in quality_levels]

plt.boxplot(data)
plt.title("Alcohol vs Quality")
plt.xlabel("Quality Levels")
plt.ylabel("Alcohol")
plt.show()

# %%
import seaborn as sns
ax=sns.countplot(x='quality',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(x='alcohol',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(x='alcohol',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(x='sulphates',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(x='pH',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(x='free sulfur dioxide',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(x='chlorides',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#quality vs pH
chem=df.groupby(['quality'],as_index=False)['pH'].sum().sort_values(by='pH',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='quality',y='pH',data=chem)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
#quality vs total sulfur dioxide
chem=df.groupby(['quality'],as_index=False)['total sulfur dioxide'].sum().sort_values(by='total sulfur dioxide',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='quality',y='total sulfur dioxide',data=chem)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
#quality vs fixed acidity
chem=df.groupby(['quality'],as_index=False)['fixed acidity'].sum().sort_values(by='fixed acidity',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='quality',y='fixed acidity',data=chem)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
chem=df.groupby(['free sulfur dioxide'],as_index=False)['total sulfur dioxide'].sum().sort_values(by='total sulfur dioxide',ascending=False)
sns.set(rc={'figure.figsize':(25,5)})
sns.barplot(x='free sulfur dioxide',y='total sulfur dioxide',data=chem)
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %%
chem=df.groupby(['sulphates'],as_index=False)['chlorides'].sum().sort_values(by='chlorides',ascending=False)
sns.set(rc={'figure.figsize':(35,5)})
sns.barplot(x='sulphates',y='chlorides',data=chem)
# Out:
# <Axes: xlabel='sulphates', ylabel='chlorides'>

# %%
#alcohol vs pH
chem=df.groupby(['alcohol'],as_index=False)['pH'].sum().sort_values(by='pH',ascending=False)
sns.set(rc={'figure.figsize':(35,5)})
sns.barplot(x='alcohol',y='pH',data=chem)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
